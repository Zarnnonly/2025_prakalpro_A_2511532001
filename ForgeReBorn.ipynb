# %% [markdown]
# <a href="https://colab.research.google.com/github/Zarnnonly/2025_prakalpro_A_2511532001/blob/main/ForgeReBorn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Simple Stable Diffusion WebUI Forge Install
# %cd /content
# !rm -rf /content/sd-webui-forge-classic
# !pip install --force-reinstall --no-deps torch==2.6.0+cu118 torchvision==0.21.0+cu118 torchaudio==2.6.0+cu118 --index-url https://download.pytorch.org/whl/cu118
# !git clone https://github.com/Haoming02/sd-webui-forge-classic.git /content/sd-webui-forge-classic
# %cd /content/sd-webui-forge-classic
# !mkdir -p models/Stable-diffusion models/VAE
# !aria2c -x 16 -s 16 "https://civitai.com/api/download/models/2167369?type=Model\&format=SafeTensor\&size=pruned\&fp=fp16" -o models/Stable-diffusion/waiNSFWIllustrious_v150.safetensors
# !sed -i "s/raise RuntimeError(\"PyTorch is not able to access CUDA\")/print(\"Warning: CUDA check bypassed for Colab compatibility\")/" modules/launch_utils.py
# !pip install "gradio==3.44.4" "pydantic==1.10.22"
# !python launch.py --skip-python-version-check --share --enable-insecure-extension-access --disable-safe-unpickle --theme dark --xformers
# Out:
# /content
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
